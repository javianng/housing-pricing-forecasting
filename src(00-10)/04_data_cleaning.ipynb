# %% [markdown]
# ## Data Cleaning Overview
# - Merge the two resale flat price datasets
# - Remove irrelevant data.
# - Convert data type.
# - Standardise formatting.
# - Handle missing values.

# %% [markdown]
# ### HDB ResaleFlatPrices Data Cleaning

# %%
import pandas as pd

# %%
df_hdb = pd.read_csv('../data/ResaleFlatPrices/ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv')
# print out length of data
print(len(df_hdb))
df_hdb.head()
# Out:
# 37153
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price
# 0      255000.0
# 1      275000.0
# 2      285000.0
# 3      290000.0
# 4      290000.0

# %%
df_hdb2 = pd.read_csv('../data/ResaleFlatPrices/ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv')
print(len(df_hdb2))
df_hdb2.head()
# Out:
# 174242
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %% [markdown]
# We need to convert `remaining_lease` into `float` instead of a string.

# %%
df_hdb2[['years', 'months']] = df_hdb2['remaining_lease'].str.split(' years ', expand=True)
# remove months from the months column
df_hdb2['months'] = df_hdb2['months'].str.replace(' months', '')
df_hdb2['months'] = df_hdb2['months'].str.replace(' month', '') # account for single month
# remove years from the years column
df_hdb2['years'] = df_hdb2['years'].str.replace('years', '')
# convert years and months to numeric values
df_hdb2['years'] = pd.to_numeric(df_hdb2['years'])
df_hdb2['months'] = pd.to_numeric(df_hdb2['months'].replace('', 0)) # account for empty months
# convert months into years and add it to years, then update remaining_lease column
df_hdb2['remaining_lease'] = df_hdb2['years'] + df_hdb2['months'].div(12).round(2)
# drop years and months columns
df_hdb2.drop(columns=['years', 'months'], inplace=True)
df_hdb2.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            44.0        Improved                 1979            61.33
# 1            67.0  New Generation                 1978            60.58
# 2            67.0  New Generation                 1980            62.42
# 3            68.0  New Generation                 1980            62.08
# 4            67.0  New Generation                 1980            62.42
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %% [markdown]
# We then convert the `hdb_df`'s `remaining_lease` column into float as well.

# %%
# convert remaining_lease of df_hdb to float
df_hdb['remaining_lease'] = df_hdb['remaining_lease'].astype(float)
df_hdb.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986             70.0
# 1            68.0  New Generation                 1981             65.0
# 2            69.0  New Generation                 1980             64.0
# 3            68.0  New Generation                 1979             63.0
# 4            68.0  New Generation                 1980             64.0
#
#    resale_price
# 0      255000.0
# 1      275000.0
# 2      285000.0
# 3      290000.0
# 4      290000.0

# %% [markdown]
# Merge the two datasets.

# %%
# merge the two dataframes
df_hdb = pd.concat([df_hdb, df_hdb2], axis=0)
print(len(df_hdb))
df_hdb.head()
# Out:
# 211395
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986             70.0
# 1            68.0  New Generation                 1981             65.0
# 2            69.0  New Generation                 1980             64.0
# 3            68.0  New Generation                 1979             63.0
# 4            68.0  New Generation                 1980             64.0
#
#    resale_price
# 0      255000.0
# 1      275000.0
# 2      285000.0
# 3      290000.0
# 4      290000.0

# %% [markdown]
# #### Convert new column `address` from `block` and `street_name`

# %%
df_hdb['address'] = df_hdb['block'] + " " + df_hdb['street_name']
df_hdb.head(10)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
# 5  2015-01  ANG MO KIO    3 ROOM   603   ANG MO KIO AVE 5     07 TO 09
# 6  2015-01  ANG MO KIO    3 ROOM   709   ANG MO KIO AVE 8     01 TO 03
# 7  2015-01  ANG MO KIO    3 ROOM   333   ANG MO KIO AVE 1     01 TO 03
# 8  2015-01  ANG MO KIO    3 ROOM   109   ANG MO KIO AVE 4     01 TO 03
# 9  2015-01  ANG MO KIO    3 ROOM   564   ANG MO KIO AVE 3     13 TO 15
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986             70.0
# 1            68.0  New Generation                 1981             65.0
# 2            69.0  New Generation                 1980             64.0
# 3            68.0  New Generation                 1979             63.0
# 4            68.0  New Generation                 1980             64.0
# 5            67.0  New Generation                 1980             64.0
# 6            68.0  New Generation                 1980             64.0
# 7            68.0  New Generation                 1981             65.0
# 8            67.0  New Generation                 1978             62.0
# 9            68.0  New Generation                 1985             69.0
#
#    resale_price                address
# 0      255000.0   174 ANG MO KIO AVE 4
# 1      275000.0  541 ANG MO KIO AVE 10
# 2      285000.0   163 ANG MO KIO AVE 4
# 3      290000.0  446 ANG MO KIO AVE 10
# 4      290000.0  557 ANG MO KIO AVE 10
# 5      290000.0   603 ANG MO KIO AVE 5
# 6      290000.0   709 ANG MO KIO AVE 8
# 7      293000.0   333 ANG MO KIO AVE 1
# 8      300000.0   109 ANG MO KIO AVE 4
# 9      307500.0   564 ANG MO KIO AVE 3

# %% [markdown]
# ### Convert addresses to lat/lng coordinates
# Purpose: To use coordinates to calculate distance
#
# How: Use OneMapSG API to convert address to coordinates

# %%
import sys
sys.path.append('../api')

from onemapsg_api import  get_geocoordinates_from_address

# %%
address_list = df_hdb['address'].unique().tolist()
len(address_list)
# Out:
# 9576

# %%
latitude_list, longitude_list = [], []

count = 1
for address in address_list:
    try:
        geocoordinates = get_geocoordinates_from_address(address)
        # print(count, geocoordinates)
    except ConnectionError:
        geocoordinates = ("TBC", "TBC")
   
    latitude, longitude = geocoordinates
    
    latitude_list.append(latitude)
    longitude_list.append(longitude)
    count += 1

print(len(latitude_list), len(longitude_list))
# Out:
# 9576 9576

# %% [markdown]
# Match the coordinates to each unique HDB flat.

# %%
df_hdb_coordinates = pd.DataFrame({'address': address_list, 'latitude': latitude_list, 'longitude': longitude_list})
df_hdb_coordinates.head(5)
# Out:
#                  address          latitude         longitude
# 0   174 ANG MO KIO AVE 4  1.37509746867904   103.83761896123
# 1  541 ANG MO KIO AVE 10  1.37392239168826  103.855621371068
# 2   163 ANG MO KIO AVE 4  1.37355178595963  103.838168959329
# 3  446 ANG MO KIO AVE 10  1.36776094720351   103.85535715026
# 4  557 ANG MO KIO AVE 10   1.3716257020332  103.857736107527

# %% [markdown]
# We save the HDB coordinates to a CSV file just in case we need to use it later.

# %%
df_hdb_coordinates.to_csv('../data/modified/hdb_coordinates.csv')

# %% [markdown]
# Now, we merge the coordinates to the main dataframe and match the coordinates with the respective addresses.

# %%
merged_df = pd.merge(df_hdb, df_hdb_coordinates, on='address', how='left')
merged_df.head(10)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
# 5  2015-01  ANG MO KIO    3 ROOM   603   ANG MO KIO AVE 5     07 TO 09
# 6  2015-01  ANG MO KIO    3 ROOM   709   ANG MO KIO AVE 8     01 TO 03
# 7  2015-01  ANG MO KIO    3 ROOM   333   ANG MO KIO AVE 1     01 TO 03
# 8  2015-01  ANG MO KIO    3 ROOM   109   ANG MO KIO AVE 4     01 TO 03
# 9  2015-01  ANG MO KIO    3 ROOM   564   ANG MO KIO AVE 3     13 TO 15
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986             70.0
# 1            68.0  New Generation                 1981             65.0
# 2            69.0  New Generation                 1980             64.0
# 3            68.0  New Generation                 1979             63.0
# 4            68.0  New Generation                 1980             64.0
# 5            67.0  New Generation                 1980             64.0
# 6            68.0  New Generation                 1980             64.0
# 7            68.0  New Generation                 1981             65.0
# 8            67.0  New Generation                 1978             62.0
# 9            68.0  New Generation                 1985             69.0
#
#    resale_price                address          latitude         longitude
# 0      255000.0   174 ANG MO KIO AVE 4  1.37509746867904   103.83761896123
# 1      275000.0  541 ANG MO KIO AVE 10  1.37392239168826  103.855621371068
# 2      285000.0   163 ANG MO KIO AVE 4  1.37355178595963  103.838168959329
# 3      290000.0  446 ANG MO KIO AVE 10  1.36776094720351   103.85535715026
# 4      290000.0  557 ANG MO KIO AVE 10   1.3716257020332  103.857736107527
# 5      290000.0   603 ANG MO KIO AVE 5  1.38020079047279   103.83575571651
# 6      290000.0   709 ANG MO KIO AVE 8  1.37113720765377  103.847662320064
# 7      293000.0   333 ANG MO KIO AVE 1   1.3613425564061  103.851698621454
# 8      300000.0   109 ANG MO KIO AVE 4  1.37009653758337  103.837687775294
# 9      307500.0   564 ANG MO KIO AVE 3  1.36984837555524  103.859404131956

# %%
merged_df.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining_lease        float64
# resale_price           float64
# address                 object
# latitude                object
# longitude               object
# dtype: object

# %% [markdown]
# We then save the dataframe into a working csv file for further feature engineering.

# %%
merged_df.to_csv('../data/modified/hdb_working_data.csv', index=False)

# %% [markdown]
# ### Cleaning the `mrt_stations.csv` dataset

# %% [markdown]
# We will remove the rows where the MRT stations have yet to be opened

# %%
# load hdb_coordinates.csv
mrt_stations = pd.read_csv('../data/modified/mrt_stations.csv')
print(mrt_stations.shape)
mrt_stations.head()
# Out:
# (185, 4)
#            mrt_station_name  latitude   longitude      opening_date
# 0   Jurong East MRT Station  1.333333  103.742222   5 November 1988
# 1   Bukit Batok MRT Station  1.349167  103.749722     10 March 1990
# 2  Bukit Gombak MRT Station  1.358611  103.751667     10 March 1990
# 3     Brickland MRT Station  1.368611  103.749444    Not opened yet
# 4       Yew Tee MRT Station  1.396986  103.747239  10 February 1996

# %%
# remove rows that have "Not opened yet" as values in the opening_date column
mrt_stations = mrt_stations[mrt_stations['opening_date'] != 'Not opened yet'].reset_index(drop=True)
print(mrt_stations.shape)
mrt_stations.head()
# Out:
# (129, 4)
#            mrt_station_name  latitude   longitude      opening_date
# 0   Jurong East MRT Station  1.333333  103.742222   5 November 1988
# 1   Bukit Batok MRT Station  1.349167  103.749722     10 March 1990
# 2  Bukit Gombak MRT Station  1.358611  103.751667     10 March 1990
# 3       Yew Tee MRT Station  1.396986  103.747239  10 February 1996
# 4        Kranji MRT Station  1.425047  103.761853  10 February 1996

# %% [markdown]
# We noted that Clementi MRT station's Wiki page had additional information for the opening date: `12 March 1988 (1988-03-12) (East West line)`, so we will remove it manually.

# %%
# remove additional information '12 March 1988 (1988-03-12) (East West line)' from Clementi MRT station 
mrt_stations.loc[mrt_stations['mrt_station_name'] == 'Clementi MRT Station', 'opening_date'] = '12 March 1988'
mrt_stations.loc[mrt_stations['mrt_station_name'] == 'Clementi MRT Station']
# Out:
#         mrt_station_name  latitude   longitude   opening_date
# 46  Clementi MRT Station  1.315303  103.765244  12 March 1988

# %%
# update the csv file
mrt_stations.to_csv('../data/modified/mrt_stations.csv', index=False)

# %% [markdown]
# ### Cleaning the BTO Supply dataset

# %%
# load bto supply dataset
bto_supply = pd.read_csv("../data/BTO Supply Data (2004-2024).csv")
print(bto_supply.shape)
bto_supply.head(15)
# Out:
# (445, 7)
#       Town name  BTO name . . . . . .     Launch    Estimated    Number  \
# 0           NaN                   NaN       date   completion  of units
# 1           NaN                   NaN        NaN  date (note)       NaN
# 2        Yishun         Acacia Breeze  24-Nov-11      1Q 2015       834
# 3     Woodlands       Admiralty Flora  22-May-14      2Q 2017       402
# 4     Woodlands       Admiralty Grove  26-Nov-13      3Q 2017       993
# 5   Bukit Merah       Alexandra Peaks   5-Dec-23    59 months       904
# 6   Bukit Merah  Alexandra Vale (PLH)  30-Aug-22      2Q 2028       782
# 7      Bidadari         Alkaff Breeze   4-Feb-21      2Q 2024       353
# 8      Bidadari      Alkaff CourtView  17-Nov-15      2Q 2020      1258
# 9      Bidadari       Alkaff LakeView  17-Nov-15      4Q 2019       531
# 10     Bidadari          Alkaff Oasis  24-Feb-16      4Q 2020      1594
# 11     Bidadari          Alkaff Vista  17-Nov-15      3Q 2019       350
# 12     Sengkang       Anchorvale Cove  25-Apr-11      4Q 2014      1011
# 13     Sengkang     Anchorvale Fields  25-Nov-14      2Q 2018       511
# 14     Sengkang    Anchorvale Harvest  22-Sep-11      3Q 2014       717
#
#     Brochure  Unnamed: 6
# 0     (note)         NaN
# 1        NaN         NaN
# 2        NaN  Info Plans
# 3   Brochure  Info Plans
# 4   Brochure  Info Plans
# 5   Brochure         NaN
# 6   Brochure         NaN
# 7   Brochure         NaN
# 8   Brochure         NaN
# 9   Brochure         NaN
# 10  Brochure         NaN
# 11  Brochure         NaN
# 12       NaN  Info Plans
# 13  Brochure         NaN
# 14       NaN  Info Plans

# %%
# drop the first 2 rows
bto_supply = bto_supply.iloc[2:]
# also drop any rows that do not have values for Launch, Estimated and Number
bto_supply = bto_supply.dropna(subset=['Launch', 'Estimated', 'Number']).reset_index(drop=True)
print(bto_supply.shape)
bto_supply.head()
# Out:
# (436, 7)
#      Town name  BTO name . . . . . .     Launch  Estimated Number  Brochure  \
# 0       Yishun         Acacia Breeze  24-Nov-11    1Q 2015    834       NaN
# 1    Woodlands       Admiralty Flora  22-May-14    2Q 2017    402  Brochure
# 2    Woodlands       Admiralty Grove  26-Nov-13    3Q 2017    993  Brochure
# 3  Bukit Merah       Alexandra Peaks   5-Dec-23  59 months    904  Brochure
# 4  Bukit Merah  Alexandra Vale (PLH)  30-Aug-22    2Q 2028    782  Brochure
#
#    Unnamed: 6
# 0  Info Plans
# 1  Info Plans
# 2  Info Plans
# 3         NaN
# 4         NaN

# %% [markdown]
# We will be using the launch dates later on, we shall standardise the format to be DD-MMM-YY. For entries that do have any days (DD) we shall standardise it to the first of the month.

# %%
# convert the launch column to the format DD-MMM-YY
def convert_launch_date(launch_date):
    launch_date = launch_date.split('-')
    # print(launch_date)
    if len(launch_date) == 1: # to handle dates like Dec 2004
        launch_date = launch_date[0].split('\xa0')
        month = launch_date[0]
        year = launch_date[1][2:]
        launch_date = '01-' + month + '-' + year
    elif len(launch_date) == 2:
        launch_date = '01-' + launch_date[0] + '-' + launch_date[1]
    else:
        day = launch_date[0]
        month = launch_date[1]
        year = launch_date[2]
        if len(day) == 1:
            day = '0' + day
        launch_date = day + '-' + month + '-' + year
    return launch_date

print(convert_launch_date('2-May-04'))
print(convert_launch_date('May-04'))
print(convert_launch_date('23-May-04'))
print(convert_launch_date('Dec 2003'))
# Out:
# 02-May-04
# 01-May-04
# 23-May-04
# 01-Dec-03

# %%
# apply convert_launch_date to the launch column
bto_supply['Launch'] = bto_supply['Launch'].apply(convert_launch_date)
bto_supply.head()
# Out:
#      Town name  BTO name . . . . . .     Launch  Estimated Number  Brochure  \
# 0       Yishun         Acacia Breeze  24-Nov-11    1Q 2015    834       NaN
# 1    Woodlands       Admiralty Flora  22-May-14    2Q 2017    402  Brochure
# 2    Woodlands       Admiralty Grove  26-Nov-13    3Q 2017    993  Brochure
# 3  Bukit Merah       Alexandra Peaks  05-Dec-23  59 months    904  Brochure
# 4  Bukit Merah  Alexandra Vale (PLH)  30-Aug-22    2Q 2028    782  Brochure
#
#    Unnamed: 6
# 0  Info Plans
# 1  Info Plans
# 2  Info Plans
# 3         NaN
# 4         NaN

# %%
# check if number column has any non-numeric values
bto_supply[~bto_supply['Number'].str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [Town name, BTO name . . . . . ., Launch, Estimated, Number, Brochure, Unnamed: 6]
# Index: []

# %% [markdown]
# Now we add the respective BTO coordinates based on `Town name` and `BTO name`, but before that we must update the BTO name column first

# %%
# update BTO name column 
bto_supply['BTO name'] = bto_supply['BTO name . . . . . .'].str.replace('BTO', 'BTO name . . . . . .')
# drop the prev column 
bto_supply = bto_supply.drop(columns=['BTO name . . . . . .'])
bto_supply.head()
# Out:
#      Town name     Launch  Estimated Number  Brochure  Unnamed: 6  \
# 0       Yishun  24-Nov-11    1Q 2015    834       NaN  Info Plans
# 1    Woodlands  22-May-14    2Q 2017    402  Brochure  Info Plans
# 2    Woodlands  26-Nov-13    3Q 2017    993  Brochure  Info Plans
# 3  Bukit Merah  05-Dec-23  59 months    904  Brochure         NaN
# 4  Bukit Merah  30-Aug-22    2Q 2028    782  Brochure         NaN
#
#                BTO name
# 0         Acacia Breeze
# 1       Admiralty Flora
# 2       Admiralty Grove
# 3       Alexandra Peaks
# 4  Alexandra Vale (PLH)

# %% [markdown]
# Remove (PLH) from BTO name

# %%
# remove (PLH) from the BTO name    
bto_supply['BTO name'] = bto_supply['BTO name'].str.replace(' (PLH)', '')

# %% [markdown]
# Then we combine the `Town name` and `BTO name` for querying the BTO later

# %%
# create new column for BTO
bto_supply['BTO'] = bto_supply['Town name'] + ' ' + bto_supply['BTO name']
bto_supply.head()
# Out:
#      Town name     Launch  Estimated Number  Brochure  Unnamed: 6  \
# 0       Yishun  24-Nov-11    1Q 2015    834       NaN  Info Plans
# 1    Woodlands  22-May-14    2Q 2017    402  Brochure  Info Plans
# 2    Woodlands  26-Nov-13    3Q 2017    993  Brochure  Info Plans
# 3  Bukit Merah  05-Dec-23  59 months    904  Brochure         NaN
# 4  Bukit Merah  30-Aug-22    2Q 2028    782  Brochure         NaN
#
#           BTO name                          BTO
# 0    Acacia Breeze         Yishun Acacia Breeze
# 1  Admiralty Flora    Woodlands Admiralty Flora
# 2  Admiralty Grove    Woodlands Admiralty Grove
# 3  Alexandra Peaks  Bukit Merah Alexandra Peaks
# 4   Alexandra Vale   Bukit Merah Alexandra Vale

# %% [markdown]
# Now we add the coordinates of the BTO using the `get_geocoordinates_from_address` function.

# %%
# iterate through bto_supply dataframe and create new columns for latitude and longitude
latitude_list = []
longitude_list = []

for index, row in bto_supply.iterrows():
    bto_name = row['BTO name']
    geocoordinates = get_geocoordinates_from_address(bto_name)
    latitude, longitude = geocoordinates
    latitude_list.append(latitude)
    longitude_list.append(longitude)

bto_supply['latitude'] = latitude_list
bto_supply['longitude'] = longitude_list
bto_supply.head(10)
# Out:
#      Town name     Launch  Estimated Number  Brochure  Unnamed: 6  \
# 0       Yishun  24-Nov-11    1Q 2015    834       NaN  Info Plans
# 1    Woodlands  22-May-14    2Q 2017    402  Brochure  Info Plans
# 2    Woodlands  26-Nov-13    3Q 2017    993  Brochure  Info Plans
# 3  Bukit Merah  05-Dec-23  59 months    904  Brochure         NaN
# 4  Bukit Merah  30-Aug-22    2Q 2028    782  Brochure         NaN
# 5     Bidadari  04-Feb-21    2Q 2024    353  Brochure         NaN
# 6     Bidadari  17-Nov-15    2Q 2020   1258  Brochure         NaN
# 7     Bidadari  17-Nov-15    4Q 2019    531  Brochure         NaN
# 8     Bidadari  24-Feb-16    4Q 2020   1594  Brochure         NaN
# 9     Bidadari  17-Nov-15    3Q 2019    350  Brochure         NaN
#
#            BTO name                          BTO          latitude  \
# 0     Acacia Breeze         Yishun Acacia Breeze  1.41840746777827
# 1   Admiralty Flora    Woodlands Admiralty Flora  1.44062992421831
# 2   Admiralty Grove    Woodlands Admiralty Grove  1.43793037367291
# 3   Alexandra Peaks  Bukit Merah Alexandra Peaks  1.29153623788484
# 4    Alexandra Vale   Bukit Merah Alexandra Vale  1.29003540887116
# 5     Alkaff Breeze       Bidadari Alkaff Breeze  1.33674489248516
# 6  Alkaff CourtView    Bidadari Alkaff CourtView  1.33623671562033
# 7   Alkaff LakeView     Bidadari Alkaff LakeView  1.33645283610396
# 8      Alkaff Oasis        Bidadari Alkaff Oasis  1.33454220029198
# 9      Alkaff Vista        Bidadari Alkaff Vista  1.33378443640283
#
#           longitude
# 0  103.844547664772
# 1  103.806198056529
# 2  103.804571100201
# 3  103.821536625633
# 4  103.818435882644
# 5  103.874525998995
# 6  103.871287596113
# 7   103.87276093968
# 8  103.872229402632
# 9  103.870408260143

# %%
# identify the rows that have 'NA' as values for latitude and longitude (just check one is enough)
bto_supply_na = bto_supply[bto_supply['latitude'] == 'NA']
bto_supply_na
# Out:
#            Town name     Launch          Estimated Number  Brochure  \
# 20           Punggol  01-Dec-04          Cancelled    734       NaN
# 21            Yishun  23-Nov-22            2Q 2028    699  Brochure
# 22          Sengkang  01-Dec-03             Dec-07    429       NaN
# 24          Sengkang  01-Mar-04             Mar-08    424       NaN
# 29             Bedok  21-Feb-24          38 months    433       NaN
# 32             Bedok  21-Feb-24          40 months    528       NaN
# 33             Bedok  30-May-23            3Q 2027   1640  Brochure
# 44            Tengah  28-Feb-23            4Q 2027   1641  Brochure
# 75          Sengkang  01-Dec-04          Cancelled    655       NaN
# 77           Punggol  01-Jun-05             Jun-09    369       NaN
# 78           Punggol  01-Feb-06             Feb-10    365       NaN
# 94         Sembawang  26-Mar-14            2Q 2017    480  Brochure
# 103  Kallang Whampoa  30-May-23            4Q 2027    569  Brochure
# 104  Kallang Whampoa  28-Feb-23            2Q 2028   1274  Brochure
# 124         Sengkang  01-Jul-06             Jul-10    508       NaN
# 125         Sengkang  01-May-07             May-11    678       NaN
# 128        Sembawang  01-Apr-01          Cancelled    410       NaN
# 135           Tengah  23-Nov-22            1Q 2027   2077  Brochure
# 155      Bukit Merah  30-Aug-22            4Q 2028    869  Brochure
# 170      Jurong East  30-Aug-22            2Q 2028    562  Brochure
# 171      Jurong West  28-Feb-23            3Q 2027    271  Brochure
# 180    Choa Chu Kang  30-Aug-22            4Q 2026    987  Brochure
# 184    Choa Chu Kang  21-Nov-12            3Q 2016   1159  Brochure
# 193  Kallang Whampoa  17-Feb-22            3Q 2027    398  Brochure
# 205          Punggol  21-Feb-24          37 months    962       NaN
# 212           Yishun  23-Nov-22            2Q 2029   1334  Brochure
# 228           Tengah  30-May-23  1Q 2027 – 2Q 2027   1985  Brochure
# 243           Tengah  30-May-23            3Q 2027    971  Brochure
# 269       Queenstown  23-Nov-22            4Q 2028    751  Brochure
# 270       Queenstown  11-Aug-21            3Q 2027    610  Brochure
# 274  Kallang Whampoa  28-Feb-23            2Q 2028    510  Brochure
# 295        Serangoon  30-May-23            3Q 2027    330  Brochure
# 307  Kallang Whampoa  24-Sep-14            1Q 2019    738  Brochure
# 342       Queenstown  21-Feb-24          58 months    251       NaN
# 355         Sengkang  01-Dec-02             Dec-06    434       NaN
# 373       Queenstown  23-Nov-22            3Q 2029   1330  Brochure
# 374       Queenstown  28-Feb-23            2Q 2029    732  Brochure
# 375       Queenstown  05-Dec-23          59 months    890  Brochure
# 379           Yishun  23-Nov-22            2Q 2029    961  Brochure
# 400      Bukit Batok  23-Nov-22            1Q 2028    790  Brochure
# 411        Woodlands  21-Feb-24       39/39 months   1127       NaN
# 420        Woodlands  30-Aug-22            1Q 2027    630  Brochure
#
#      Unnamed: 6                           BTO name  \
# 20          NaN                            Anthias
# 21          NaN             Aranda Breeze @ Yishun
# 22          NaN                          Aspella 1
# 24          NaN                           Atrina 1
# 29          NaN                Bedok North Springs
# 32          NaN                  Bedok South Bloom
# 33          NaN               Bedok South Blossoms
# 44          NaN                    Brickland Weave
# 75          NaN                        Coral Green
# 77          NaN                        Coralinus 1
# 78          NaN                        Coralinus 2
# 94   Info Plans                EastLace @ Camberra
# 103         NaN                  Farrer Park Arena
# 104         NaN                 Farrer Park Fields
# 124         NaN                   Fernvale Vista 1
# 125         NaN                   Fernvale Vista 2
# 128         NaN                   Flowing Greenery
# 135         NaN  Garden Waterfront I & II @ Tengah
# 155         NaN                  Havelock Hillside
# 170         NaN                 Jurong East Breeze
# 171         NaN                Jurong West Crystal
# 180         NaN                   Keat Hong Grange
# 184  Info Plans                   Keat Kong Mirage
# 193         NaN              King George’s Heights
# 205         NaN                  Matilda Riverside
# 212         NaN           Miltonia Breeze @ Yishun
# 228         NaN               Parc Meadow @ Tengah
# 243         NaN                   Plantation Verge
# 269         NaN                   Queensway Canopy
# 270         NaN                        Queen’s Arc
# 274         NaN                       Rajah Summit
# 295         NaN              Serangoon North Vista
# 307         NaN                St. George’s Towers
# 342         NaN             Tanglin Halt Courtyard
# 355         NaN                        The Coris 1
# 373         NaN                   Ulu Pandan Banks
# 374         NaN                  Ulu Pandan Glades
# 375         NaN                   Ulu Pandan Vista
# 379         NaN              Vanda Breeze @ Yishun
# 400         NaN          West Glades @ Bukit Batok
# 411         NaN                     Woodgrove Edge
# 420         NaN             Woodlands South Plains
#
#                                           BTO latitude longitude
# 20                            Punggol Anthias       NA        NA
# 21              Yishun Aranda Breeze @ Yishun       NA        NA
# 22                         Sengkang Aspella 1       NA        NA
# 24                          Sengkang Atrina 1       NA        NA
# 29                  Bedok Bedok North Springs       NA        NA
# 32                    Bedok Bedok South Bloom       NA        NA
# 33                 Bedok Bedok South Blossoms       NA        NA
# 44                     Tengah Brickland Weave       NA        NA
# 75                       Sengkang Coral Green       NA        NA
# 77                        Punggol Coralinus 1       NA        NA
# 78                        Punggol Coralinus 2       NA        NA
# 94              Sembawang EastLace @ Camberra       NA        NA
# 103         Kallang Whampoa Farrer Park Arena       NA        NA
# 104        Kallang Whampoa Farrer Park Fields       NA        NA
# 124                 Sengkang Fernvale Vista 1       NA        NA
# 125                 Sengkang Fernvale Vista 2       NA        NA
# 128                Sembawang Flowing Greenery       NA        NA
# 135  Tengah Garden Waterfront I & II @ Tengah       NA        NA
# 155             Bukit Merah Havelock Hillside       NA        NA
# 170            Jurong East Jurong East Breeze       NA        NA
# 171           Jurong West Jurong West Crystal       NA        NA
# 180            Choa Chu Kang Keat Hong Grange       NA        NA
# 184            Choa Chu Kang Keat Kong Mirage       NA        NA
# 193     Kallang Whampoa King George’s Heights       NA        NA
# 205                 Punggol Matilda Riverside       NA        NA
# 212           Yishun Miltonia Breeze @ Yishun       NA        NA
# 228               Tengah Parc Meadow @ Tengah       NA        NA
# 243                   Tengah Plantation Verge       NA        NA
# 269               Queenstown Queensway Canopy       NA        NA
# 270                    Queenstown Queen’s Arc       NA        NA
# 274              Kallang Whampoa Rajah Summit       NA        NA
# 295           Serangoon Serangoon North Vista       NA        NA
# 307       Kallang Whampoa St. George’s Towers       NA        NA
# 342         Queenstown Tanglin Halt Courtyard       NA        NA
# 355                      Sengkang The Coris 1       NA        NA
# 373               Queenstown Ulu Pandan Banks       NA        NA
# 374              Queenstown Ulu Pandan Glades       NA        NA
# 375               Queenstown Ulu Pandan Vista       NA        NA
# 379              Yishun Vanda Breeze @ Yishun       NA        NA
# 400     Bukit Batok West Glades @ Bukit Batok       NA        NA
# 411                  Woodlands Woodgrove Edge       NA        NA
# 420          Woodlands Woodlands South Plains       NA        NA

# %% [markdown]
# We can use the OpenStreetMap API to see if we can identify the coordinates of these flats.

# %%
import sys
sys.path.append('../')

from api.openstreetmap_api import get_bto_coordinates

for index, row in bto_supply_na.iterrows():
    bto_name = row['BTO']
    geocoordinates = get_bto_coordinates(bto_name)
    print(bto_name, geocoordinates)
    latitude, longitude = geocoordinates
    bto_supply.at[index, 'latitude'] = latitude
    bto_supply.at[index, 'longitude'] = longitude

# check if there are any rows with None as values for latitude and longitude
bto_supply_na = bto_supply[bto_supply['latitude'].isna()]
bto_supply_na
# Out:
#            Town name     Launch  Estimated Number  Brochure  Unnamed: 6  \
# 20           Punggol  01-Dec-04  Cancelled    734       NaN         NaN
# 75          Sengkang  01-Dec-04  Cancelled    655       NaN         NaN
# 94         Sembawang  26-Mar-14    2Q 2017    480  Brochure  Info Plans
# 103  Kallang Whampoa  30-May-23    4Q 2027    569  Brochure         NaN
# 104  Kallang Whampoa  28-Feb-23    2Q 2028   1274  Brochure         NaN
# 124         Sengkang  01-Jul-06     Jul-10    508       NaN         NaN
# 125         Sengkang  01-May-07     May-11    678       NaN         NaN
# 128        Sembawang  01-Apr-01  Cancelled    410       NaN         NaN
# 135           Tengah  23-Nov-22    1Q 2027   2077  Brochure         NaN
# 184    Choa Chu Kang  21-Nov-12    3Q 2016   1159  Brochure  Info Plans
# 193  Kallang Whampoa  17-Feb-22    3Q 2027    398  Brochure         NaN
# 274  Kallang Whampoa  28-Feb-23    2Q 2028    510  Brochure         NaN
# 307  Kallang Whampoa  24-Sep-14    1Q 2019    738  Brochure         NaN
# 342       Queenstown  21-Feb-24  58 months    251       NaN         NaN
#
#                               BTO name  \
# 20                             Anthias
# 75                         Coral Green
# 94                 EastLace @ Camberra
# 103                  Farrer Park Arena
# 104                 Farrer Park Fields
# 124                   Fernvale Vista 1
# 125                   Fernvale Vista 2
# 128                   Flowing Greenery
# 135  Garden Waterfront I & II @ Tengah
# 184                   Keat Kong Mirage
# 193              King George’s Heights
# 274                       Rajah Summit
# 307                St. George’s Towers
# 342             Tanglin Halt Courtyard
#
#                                           BTO latitude longitude
# 20                            Punggol Anthias     None      None
# 75                       Sengkang Coral Green     None      None
# 94              Sembawang EastLace @ Camberra     None      None
# 103         Kallang Whampoa Farrer Park Arena     None      None
# 104        Kallang Whampoa Farrer Park Fields     None      None
# 124                 Sengkang Fernvale Vista 1     None      None
# 125                 Sengkang Fernvale Vista 2     None      None
# 128                Sembawang Flowing Greenery     None      None
# 135  Tengah Garden Waterfront I & II @ Tengah     None      None
# 184            Choa Chu Kang Keat Kong Mirage     None      None
# 193     Kallang Whampoa King George’s Heights     None      None
# 274              Kallang Whampoa Rajah Summit     None      None
# 307       Kallang Whampoa St. George’s Towers     None      None
# 342         Queenstown Tanglin Halt Courtyard     None      None

# %% [markdown]
# These are the BTOs that we are unable to get the cooridnates from their names. For these, we will manually scrape their addresses. But we also note that some of these flats are cancelled, so we will drop these rows.

# %%
# drop rows where Estimated is Cancelled
bto_supply = bto_supply[bto_supply['Estimated'] != 'Cancelled'].reset_index(drop=True)

# identify rows with None values for latitude and longitude
bto_supply_na = bto_supply[bto_supply['latitude'].isna()]
bto_supply_na
# Out:
#            Town name     Launch  Estimated Number  Brochure  Unnamed: 6  \
# 92         Sembawang  26-Mar-14    2Q 2017    480  Brochure  Info Plans
# 101  Kallang Whampoa  30-May-23    4Q 2027    569  Brochure         NaN
# 102  Kallang Whampoa  28-Feb-23    2Q 2028   1274  Brochure         NaN
# 122         Sengkang  01-Jul-06     Jul-10    508       NaN         NaN
# 123         Sengkang  01-May-07     May-11    678       NaN         NaN
# 132           Tengah  23-Nov-22    1Q 2027   2077  Brochure         NaN
# 181    Choa Chu Kang  21-Nov-12    3Q 2016   1159  Brochure  Info Plans
# 190  Kallang Whampoa  17-Feb-22    3Q 2027    398  Brochure         NaN
# 271  Kallang Whampoa  28-Feb-23    2Q 2028    510  Brochure         NaN
# 303  Kallang Whampoa  24-Sep-14    1Q 2019    738  Brochure         NaN
# 338       Queenstown  21-Feb-24  58 months    251       NaN         NaN
#
#                               BTO name  \
# 92                 EastLace @ Camberra
# 101                  Farrer Park Arena
# 102                 Farrer Park Fields
# 122                   Fernvale Vista 1
# 123                   Fernvale Vista 2
# 132  Garden Waterfront I & II @ Tengah
# 181                   Keat Kong Mirage
# 190              King George’s Heights
# 271                       Rajah Summit
# 303                St. George’s Towers
# 338             Tanglin Halt Courtyard
#
#                                           BTO latitude longitude
# 92              Sembawang EastLace @ Camberra     None      None
# 101         Kallang Whampoa Farrer Park Arena     None      None
# 102        Kallang Whampoa Farrer Park Fields     None      None
# 122                 Sengkang Fernvale Vista 1     None      None
# 123                 Sengkang Fernvale Vista 2     None      None
# 132  Tengah Garden Waterfront I & II @ Tengah     None      None
# 181            Choa Chu Kang Keat Kong Mirage     None      None
# 190     Kallang Whampoa King George’s Heights     None      None
# 271              Kallang Whampoa Rajah Summit     None      None
# 303       Kallang Whampoa St. George’s Towers     None      None
# 338         Queenstown Tanglin Halt Courtyard     None      None

# %% [markdown]
# Now we fit the scraped coordinates to each of these rows.

# %%
na_coordinates = [(1.446783281453086, 103.8291994247981), 
                  (1.312381004526255, 103.85160759300113), 
                  (1.3109478620703383, 103.84951107049784), 
                  (1.3921867093105702, 103.87513208062104), 
                  (1.3903500507142876, 103.87539575582275),
                  (1.3558050411261695, 103.72859069596292),
                  (1.3784647933702676, 103.74877393829188),
                  (1.3071326935324572, 103.85955008246935),
                  (1.3283620620075778, 103.85272350945661),
                  (1.3227114623559377, 103.86228102295024),
                  (1.3006211376314385, 103.7976046113048)]

# fit the coordinates to the rows with None values
for index, coordinates in zip(bto_supply_na.index, na_coordinates):
    latitude, longitude = coordinates
    bto_supply.at[index, 'latitude'] = latitude
    bto_supply.at[index, 'longitude'] = longitude

# check if there are any rows with None as values for latitude and longitude
bto_supply_na = bto_supply[bto_supply['latitude'].isna()]
bto_supply_na
# Out:
# Empty DataFrame
# Columns: [Town name, Launch, Estimated, Number, Brochure, Unnamed: 6, BTO name, BTO, latitude, longitude]
# Index: []

# %%
# export bto_supply to a csv file
bto_supply.to_csv('../data/modified/bto_supply_cleaned.csv', index=False)

# %% [markdown]
# ### Cleaning the SORA dataset

# %%
import numpy as np
import datetime as dt

# %% [markdown]
# The first 6 rows of the dataset are irrelevant so we will skip them. We will also replace `NaN` values with `None`.

# %%
data = pd.read_csv('../data/3M_SORA_rates_2005_2024.csv', skiprows=6)
data = data.replace({np.nan: None})
data.head()
# Out:
#   SORA Value Date Unnamed: 1 Unnamed: 2 SORA Publication Date  \
# 0            2005        Jul        1.0           04 Jul 2005
# 1            None       None        4.0           05 Jul 2005
# 2            None       None        5.0           06 Jul 2005
# 3            None       None        6.0           07 Jul 2005
# 4            None       None        7.0           08 Jul 2005
#
#   Compound SORA - 3 month
# 0                       -
# 1                       -
# 2                       -
# 3                       -
# 4                       -

# %% [markdown]
# We will create a new dataframe to store the final outputs. To get the final outputs, we will clean the data by extracting only relevant information, converting the data types and aggregating values based on the month.

# %%
output_df = pd.DataFrame(columns=['SORA Value Month', 'Compound SORA - 3 month'])
value_year = 2005
value_month = ''
for (index, row) in data.iterrows():
    if row.isnull().iloc[2] or row.iloc[4] == '-':
        continue
    if row.isnull().iloc[0] == False:
        value_year = row.iloc[0]
    if row.isnull().iloc[1] == False:
        value_month = row.iloc[1]
    sora_value_month = str(value_year) + ' ' + value_month
    sora_value_month = dt.datetime.strptime(sora_value_month, '%Y %b').strftime('%Y-%m')
    compound_sora = float(row.iloc[4])
    output_df.loc[len(output_df.index)] = [sora_value_month, compound_sora]
output_df = output_df.groupby(['SORA Value Month']).mean()
output_df.head()
# Out:
#                   Compound SORA - 3 month
# SORA Value Month
# 2005-10                          1.960476
# 2005-11                          2.195200
# 2005-12                          2.470248
# 2006-01                          2.795811
# 2006-02                          3.040975

# %% [markdown]
# We then write the cleaned dataframe into a csv file.

# %%
output_df.to_csv('../data/modified/3M_SORA_rates_2005_2024_cleaned.csv')
