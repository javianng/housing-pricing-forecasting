# %% [markdown]
# ### Getting schools within 1km radius of HDB flat
# In progress: 2km of flat too

# %% [markdown]
# We will first load the `hdb_working_data.csv` file

# %%
import sys
sys.path.append('../api')

import pandas as pd
from datetime import datetime
import geopandas as gpd
from shapely.geometry import Point

hdb_cleaned_df = pd.read_csv('../data/modified/hdb_working_data.csv')
hdb_cleaned_df.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986             70.0
# 1            68.0  New Generation                 1981             65.0
# 2            69.0  New Generation                 1980             64.0
# 3            68.0  New Generation                 1979             63.0
# 4            68.0  New Generation                 1980             64.0
#
#    resale_price                address  latitude   longitude      sora  \
# 0      255000.0   174 ANG MO KIO AVE 4  1.375097  103.837619  0.129019
# 1      275000.0  541 ANG MO KIO AVE 10  1.373922  103.855621  0.129019
# 2      285000.0   163 ANG MO KIO AVE 4  1.373552  103.838169  0.129019
# 3      290000.0  446 ANG MO KIO AVE 10  1.367761  103.855357  0.129019
# 4      290000.0  557 ANG MO KIO AVE 10  1.371626  103.857736  0.129019
#
#                 mrt_stations_within_1km                  nearest_mrt_station  \
# 0                                    []  Yio Chu Kang MRT Station (1099.56m)
# 1  ['Ang Mo Kio MRT Station (811.53m)']     Ang Mo Kio MRT Station (811.53m)
# 2                                    []   Yio Chu Kang MRT Station (1183.8m)
# 3  ['Ang Mo Kio MRT Station (703.32m)']     Ang Mo Kio MRT Station (703.32m)
# 4  ['Ang Mo Kio MRT Station (939.42m)']     Ang Mo Kio MRT Station (939.42m)
#
#    bto_within_4km  bto_supply_within_4km
# 0              12                   6587
# 1              39                  23252
# 2              10                   4941
# 3              34                  20043
# 4              45                  26356

# %% [markdown]
# Then we load the `schools` dataset

# %%
pri_schools = pd.read_csv('../data/PointsOfInterest/primary_school_coordinates.csv')
pri_schools.head()
# Out:
#    Unnamed: 0                          name  SAP  GEP  Affiliated_Secondary  \
# 0           0      Admiralty Primary School    0    0                     0
# 1           1  Ahmad Ibrahim Primary School    0    0                     0
# 2           2                Ai Tong School    1    0                     0
# 3           3      Alexandra Primary School    0    0                     0
# 4           4   Anchor Green Primary School    0    0                     0
#
#    latitude   longitude
# 0  1.442635  103.800040
# 1  1.433153  103.832942
# 2  1.360583  103.833020
# 3  1.291334  103.824425
# 4  1.390370  103.887165

# %% [markdown]
# Next we create a method to run through the entire `primary_school_coordinates.csv` to compare the distance between the flat and the school.
#
# *For simplicity sake, we have made the assumption that from 2015, there have been no new changes to primary school locations

# %%
# method to calculate the distance between two points
def calculate_geospatial_distance(start_coords, end_coords):
    
    # Unpack the tuples
    lat1, lon1 = start_coords
    lat2, lon2 = end_coords
    
    # Create GeoSeries from the points
    point1 = gpd.GeoSeries([Point(lon1, lat1)], crs="EPSG:4326")
    point2 = gpd.GeoSeries([Point(lon2, lat2)], crs="EPSG:4326")
    
    # Reproject to a CRS that uses meters as distance units (e.g., World Mercator)
    point1 = point1.to_crs("EPSG:3395")
    point2 = point2.to_crs("EPSG:3395")
    
    # Calculate the distance between the points
    distance = point1.distance(point2).iloc[0]  # distance in meters
    
    return distance/1000  # convert to kilometers

# Example usage
start_coords = (1.352083, 103.819836) 
end_coords = (1.290270, 103.851959)  

distance = calculate_geospatial_distance(start_coords, end_coords)
print(f"Distance: {distance} kilometers")
# Out:
# Distance: 7.715477804836227 kilometers

# %% [markdown]
# ### Getting Primary Schools within 1km of flat address

# %%
# load bto_supply dataset
pri_schools = pd.read_csv('../data/modified/primary_school_coordinates.csv')
pri_schools.head()
# Out:
#    Unnamed: 0                          name  SAP  GEP  Affiliated_Secondary  \
# 0           0      Admiralty Primary School    0    0                     0
# 1           1  Ahmad Ibrahim Primary School    0    0                     0
# 2           2                Ai Tong School    1    0                     0
# 3           3      Alexandra Primary School    0    0                     0
# 4           4   Anchor Green Primary School    0    0                     0
#
#    latitude   longitude
# 0  1.442635  103.800040
# 1  1.433153  103.832942
# 2  1.360583  103.833020
# 3  1.291334  103.824425
# 4  1.390370  103.887165

# %% [markdown]
# Now we identify the no. of pri_schools within 1km of the flat, and collate them in a list (if there are multiple) for each flat

# %%
def get_schools_within_1km(flat_coordinates, pri_schools_df):
    schools = []
    for index, row in pri_schools_df.iterrows():
        school = row['name']
        sch_latitude, sch_longitude = float(row['latitude']), float(row['longitude'])
        coordinates = (sch_latitude, sch_longitude)

        distance = calculate_geospatial_distance(flat_coordinates, coordinates)
        if 0 <= distance < 1: # original: if round(ditance) <= 1
            schools.append(f"{school} ({distance * 1000:.2f}m)")
    return (len(schools), schools)

# Sample: get_schools_within_1km((1.37509746867904, 103.83761896123), pri_schools)

# %%
def create_prisch_within_1km_columns(hdb_cleaned_df, pri_sch_df):
    processed_flats = {}
    schs_within_1km = []
    schs_within_1km_list = []

    for index, row in hdb_cleaned_df.iterrows():
        address = row['address']
        if address in processed_flats: #use existing values if alr in dict
            schs_within_1km.append(processed_flats[address][0])
            schs_within_1km_list.append(processed_flats[address][1])
        else:
            flat_coordinates = (float(row['latitude']), float(row['longitude']))
            num_schools, nearest_school_list = get_schools_within_1km(flat_coordinates, pri_sch_df)
            schs_within_1km.append(num_schools)
            schs_within_1km_list.append(nearest_school_list)
            processed_flats[address] = (num_schools, nearest_school_list)
    
    hdb_cleaned_df['pri_schs_within_1km'] = schs_within_1km_list
    hdb_cleaned_df['count_pri_schs_within_1km'] = schs_within_1km
    return hdb_cleaned_df

hdb_cleaned_df = create_prisch_within_1km_columns(hdb_cleaned_df, pri_schools)
hdb_cleaned_df.head(10)
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
# 5  2015-01  ANG MO KIO    3 ROOM   603   ANG MO KIO AVE 5     07 TO 09
# 6  2015-01  ANG MO KIO    3 ROOM   709   ANG MO KIO AVE 8     01 TO 03
# 7  2015-01  ANG MO KIO    3 ROOM   333   ANG MO KIO AVE 1     01 TO 03
# 8  2015-01  ANG MO KIO    3 ROOM   109   ANG MO KIO AVE 4     01 TO 03
# 9  2015-01  ANG MO KIO    3 ROOM   564   ANG MO KIO AVE 3     13 TO 15
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  ...  \
# 0            60.0        Improved                 1986             70.0  ...
# 1            68.0  New Generation                 1981             65.0  ...
# 2            69.0  New Generation                 1980             64.0  ...
# 3            68.0  New Generation                 1979             63.0  ...
# 4            68.0  New Generation                 1980             64.0  ...
# 5            67.0  New Generation                 1980             64.0  ...
# 6            68.0  New Generation                 1980             64.0  ...
# 7            68.0  New Generation                 1981             65.0  ...
# 8            67.0  New Generation                 1978             62.0  ...
# 9            68.0  New Generation                 1985             69.0  ...
#
#                  address  latitude   longitude      sora  \
# 0   174 ANG MO KIO AVE 4  1.375097  103.837619  0.129019
# 1  541 ANG MO KIO AVE 10  1.373922  103.855621  0.129019
# 2   163 ANG MO KIO AVE 4  1.373552  103.838169  0.129019
# 3  446 ANG MO KIO AVE 10  1.367761  103.855357  0.129019
# 4  557 ANG MO KIO AVE 10  1.371626  103.857736  0.129019
# 5   603 ANG MO KIO AVE 5  1.380201  103.835756  0.129019
# 6   709 ANG MO KIO AVE 8  1.371137  103.847662  0.129019
# 7   333 ANG MO KIO AVE 1  1.361343  103.851699  0.129019
# 8   109 ANG MO KIO AVE 4  1.370097  103.837688  0.129019
# 9   564 ANG MO KIO AVE 3  1.369848  103.859404  0.129019
#
#                 mrt_stations_within_1km                  nearest_mrt_station  \
# 0                                    []  Yio Chu Kang MRT Station (1099.56m)
# 1  ['Ang Mo Kio MRT Station (811.53m)']     Ang Mo Kio MRT Station (811.53m)
# 2                                    []   Yio Chu Kang MRT Station (1183.8m)
# 3  ['Ang Mo Kio MRT Station (703.32m)']     Ang Mo Kio MRT Station (703.32m)
# 4  ['Ang Mo Kio MRT Station (939.42m)']     Ang Mo Kio MRT Station (939.42m)
# 5                                    []  Yio Chu Kang MRT Station (1026.13m)
# 6  ['Ang Mo Kio MRT Station (234.44m)']     Ang Mo Kio MRT Station (234.44m)
# 7  ['Ang Mo Kio MRT Station (991.53m)']     Ang Mo Kio MRT Station (991.53m)
# 8                                    []    Ang Mo Kio MRT Station (1309.39m)
# 9                                    []    Ang Mo Kio MRT Station (1108.25m)
#
#   bto_within_4km  bto_supply_within_4km  \
# 0             12                   6587
# 1             39                  23252
# 2             10                   4941
# 3             34                  20043
# 4             45                  26356
# 5             16                   9077
# 6             27                  14734
# 7             28                  14701
# 8              8                   3717
# 9             46                  27317
#
#                                  pri_schs_within_1km count_pri_schs_within_1km
# 0  [Ang Mo Kio Primary School (676.95m), CHIJ St....                         3
# 1               [Jing Shan Primary School (431.03m)]                         1
# 2  [Ang Mo Kio Primary School (495.36m), CHIJ St....                         3
# 3  [Jing Shan Primary School (611.18m), Teck Ghee...                         3
# 4               [Jing Shan Primary School (627.43m)]                         1
# 5  [Anderson Primary School (771.81m), CHIJ St. N...                         3
# 6  [Ang Mo Kio Primary School (916.33m), Jing Sha...                         3
# 7  [Teck Ghee Primary School (476.75m), Townsvill...                         2
# 8  [Ang Mo Kio Primary School (232.66m), CHIJ St....                         3
# 9               [Jing Shan Primary School (851.39m)]                         1
#
# [10 rows x 21 columns]

# %%
# check count_pri_schs_within_1km column for any rows with 0 supply
hdb_na = hdb_cleaned_df[hdb_cleaned_df['count_pri_schs_within_1km'] == 0]
hdb_na
# Out:
#           month          town flat_type block         street_name  \
# 335     2015-01  CENTRAL AREA    3 ROOM    34        UPP CROSS ST
# 337     2015-01  CENTRAL AREA    3 ROOM   538        UPP CROSS ST
# 338     2015-01  CENTRAL AREA    3 ROOM   532        UPP CROSS ST
# 414     2015-01      CLEMENTI    3 ROOM   602  CLEMENTI WEST ST 1
# 423     2015-01      CLEMENTI    3 ROOM   729  CLEMENTI WEST ST 2
# ...         ...           ...       ...   ...                 ...
# 211269  2024-03     SEMBAWANG    4 ROOM  107A         CANBERRA ST
# 211271  2024-03     SEMBAWANG    4 ROOM  104B         CANBERRA ST
# 211276  2024-03     SEMBAWANG    5 ROOM  119A       CANBERRA CRES
# 211279  2024-03     SEMBAWANG    5 ROOM  121D         CANBERRA ST
# 211350  2024-03     WOODLANDS    4 ROOM    31        MARSILING DR
#
#        storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 335        16 TO 18            65.0        Improved                 1975
# 337        10 TO 12            68.0        Improved                 1978
# 338        13 TO 15            68.0        Improved                 1980
# 414        04 TO 06            67.0  New Generation                 1979
# 423        07 TO 09            82.0  New Generation                 1983
# ...             ...             ...             ...                  ...
# 211269     13 TO 15            93.0         Model A                 2018
# 211271     01 TO 03            93.0         Model A                 2018
# 211276     07 TO 09           113.0        Improved                 2018
# 211279     13 TO 15           113.0        Improved                 2018
# 211350     04 TO 06            97.0  New Generation                 1977
#
#         remaining_lease  ...                 address  latitude   longitude  \
# 335               59.00  ...         34 UPP CROSS ST  1.286235  103.842303
# 337               62.00  ...        538 UPP CROSS ST  1.285212  103.845766
# 338               64.00  ...        532 UPP CROSS ST  1.284194  103.845986
# 414               63.00  ...  602 CLEMENTI WEST ST 1  1.305104  103.766312
# 423               67.00  ...  729 CLEMENTI WEST ST 2  1.304927  103.763519
# ...                 ...  ...                     ...       ...         ...
# 211269            93.42  ...        107A CANBERRA ST  1.449905  103.832979
# 211271            93.42  ...        104B CANBERRA ST  1.450074  103.831377
# 211276              NaN  ...      119A CANBERRA CRES  1.446048  103.831125
# 211279            92.92  ...        121D CANBERRA ST  1.447038  103.833923
# 211350            52.25  ...         31 MARSILING DR  1.442986  103.772343
#
#             sora                            mrt_stations_within_1km  \
# 335     0.129019  ['Outram Park MRT Station (678.50m)', 'Chinato...
# 337     0.129019  ['Raffles Place MRT Station (642.80m)', 'Tanjo...
# 338     0.129019  ['Raffles Place MRT Station (602.41m)', 'Tanjo...
# 414     0.129019                                                 []
# 423     0.129019                                                 []
# ...          ...                                                ...
# 211269  3.635582                 ['Canberra MRT Station (839.88m)']
# 211271  3.635582                 ['Canberra MRT Station (797.89m)']
# 211276  3.635582                 ['Canberra MRT Station (365.95m)']
# 211279  3.635582                 ['Canberra MRT Station (642.45m)']
# 211350  3.635582                                                 []
#
#                     nearest_mrt_station bto_within_4km  bto_supply_within_4km  \
# 335      Chinatown MRT Station (223.2m)              9                   7841
# 337     Chinatown MRT Station (210.29m)              8                   7441
# 338     Chinatown MRT Station (249.89m)              9                   7841
# 414     Clementi MRT Station (1134.22m)              5                   2791
# 423     Clementi MRT Station (1163.53m)              5                   2791
# ...                                 ...            ...                    ...
# 211269   Canberra MRT Station (839.88m)             61                  42742
# 211271   Canberra MRT Station (797.89m)             63                  44282
# 211276   Canberra MRT Station (365.95m)             60                  41797
# 211279   Canberra MRT Station (642.45m)             58                  40257
# 211350  Marsiling MRT Station (1165.0m)             15                  10039
#
#         pri_schs_within_1km count_pri_schs_within_1km
# 335                      []                         0
# 337                      []                         0
# 338                      []                         0
# 414                      []                         0
# 423                      []                         0
# ...                     ...                       ...
# 211269                   []                         0
# 211271                   []                         0
# 211276                   []                         0
# 211279                   []                         0
# 211350                   []                         0
#
# [5863 rows x 21 columns]

# %%
# save the dataframe to csv 
hdb_cleaned_df.to_csv('../data/modified/hdb_working_data.csv', index=False)
