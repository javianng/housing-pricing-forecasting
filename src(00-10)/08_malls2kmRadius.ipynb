# %% [markdown]
# ### Objective: Create mall2kmRadius attribute
# Steps:
# 1. Create the malls dataset by scraping wikipedia information about Singapore malls
# 2. Check which malls are within 2km of the hdb and append it to the training dataset

# %% [markdown]
# #### 1.1 Scraping wikipedia mall information

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_shopping_malls_in_Singapore'
result = requests.get(url)
doc = BeautifulSoup(result.text, 'html.parser')

# %%
def convert_mall(list_item):
    for link in list_item.find_all('a'):
        if link['href'].startswith("/wiki"):
            return (list_item.text, link['href'])
    return (list_item.text,"")

# %%
mall_links = [convert_mall(list_item) 
            for div_section in doc.find_all('div', class_='div-col') 
            for list_item in div_section.find_all('li')
        ]
mall_links
# Out:
# [('100 AM[1]', ''),
#  ('313@Somerset[2]', ''),
#  ('Aperia', ''),
#  ('Balestier Hill Shopping Centre', ''),
#  ('Bugis Cube[3]', ''),
#  ('Bugis Junction', '/wiki/Bugis_Junction'),
#  ('Bugis+', '/wiki/Bugis%2B'),
#  ('Capitol Piazza', '/wiki/Capitol_Piazza'),
#  ('Cathay Cineleisure Orchard', '/wiki/Cathay_Cineleisure_Orchard'),
#  ('Clarke Quay Central', ''),
#  ('The Centrepoint', '/wiki/The_Centrepoint'),
#  ('City Square Mall', '/wiki/City_Square_Mall_(Singapore)'),
#  ('City Gate Mall[4]', ''),
#  ('CityLink Mall', '/wiki/CityLink_Mall'),
#  ('Duo', '/wiki/DUO'),
#  ('Far East Plaza', '/wiki/Far_East_Plaza'),
#  ('Funan', '/wiki/Funan,_Singapore'),
#  ('Great World City', '/wiki/Great_World_City'),
#  ('HDB Hub', '/wiki/HDB_Hub'),
#  ('Holland Village Shopping Mall', '/wiki/Holland_Village,_Singapore'),
#  ('ION Orchard', '/wiki/ION_Orchard'),
#  ('Junction 8', '/wiki/Junction_8_Shopping_Centre'),
#  ('Knightsbridge[5]', ''),
#  ('Liat Towers', '/wiki/Liat_Towers'),
#  ('Lucky Plaza', '/wiki/Lucky_Plaza'),
#  ('Marina Bay Sands', '/wiki/Marina_Bay_Sands'),
#  ('The Shoppes at Marina Bay Sands[6]', ''),
#  ('Marina Bay Link Mall', '/wiki/Marina_Bay_Link_Mall'),
#  ('Marina Square', '/wiki/Marina_Square'),
#  ('Millenia Walk', '/wiki/Millenia_Walk'),
#  ('Mustafa Shopping Centre', '/wiki/Mustafa_Centre'),
#  ('Ngee Ann City', '/wiki/Ngee_Ann_City'),
#  ('One Holland Village', ''),
#  ('Orchard Central', '/wiki/Orchard_Central'),
#  ('Orchard Gateway', '/wiki/Orchard_Gateway'),
#  ('Orchard Plaza[7]', ''),
#  ('Midpoint Orchard[8]', ''),
#  ('Palais Renaissance', '/wiki/Palais_Renaissance'),
#  ("People's Park Centre", '/wiki/People%27s_Park_Centre'),
#  ("People's Park Complex", '/wiki/People%27s_Park_Complex'),
#  ('Plaza Singapura', '/wiki/Plaza_Singapura'),
#  ('PoMo', ''),
#  ('Raffles City', '/wiki/Raffles_City_Singapore'),
#  ('Scotts Square[9]', ''),
#  ('Shaw House and Centre', '/wiki/Shaw_House_and_Centre'),
#  ('Sim Lim Square', '/wiki/Sim_Lim_Square'),
#  ('Singapore Shopping Centre', ''),
#  ('The South Beach', '/wiki/South_Beach,_Singapore'),
#  ('Square 2', '/wiki/Square_2_(shopping_mall)'),
#  ('Sunshine Plaza[10]', ''),
#  ('Suntec City', '/wiki/Suntec_City'),
#  ('Tanglin Mall[11]', ''),
#  ('Tanjong Pagar Centre', '/wiki/Tanjong_Pagar_Centre'),
#  ('Tekka Centre', '/wiki/Tekka_Centre'),
#  ('The Adelphi', ''),
#  ('The Paragon', '/wiki/The_Paragon,_Singapore'),
#  ('Tiong Bahru Plaza', '/wiki/Tiong_Bahru_Plaza'),
#  ('The Poiz[12]', ''),
#  ('Thomson Plaza', '/wiki/Thomson_Plaza'),
#  ('United Square[13]', ''),
#  ('Thomson V', ''),
#  ('Velocity@Novena Square', '/wiki/Novena_Square_Shopping_Mall'),
#  ('Wheelock Place', '/wiki/Wheelock_Place'),
#  ('Wisma Atria', '/wiki/Wisma_Atria'),
#  ('Zhongshan Mall[14]', ''),
#  ('Bedok Mall', '/wiki/Bedok_Mall'),
#  ('Century Square', '/wiki/Century_Square'),
#  ('Changi City Point', '/wiki/Changi_City_Point'),
#  ('Downtown East', '/wiki/NTUC_Downtown_East'),
#  ('Djitsun Mall Bedok', ''),
#  ('Eastpoint Mall', '/wiki/Eastpoint_Mall,_Singapore'),
#  ('Jewel Changi Airport', '/wiki/Jewel_Changi_Airport'),
#  ('KINEX (formerly OneKM)', ''),
#  ('Katong Shopping Centre', '/wiki/Katong_Shopping_Centre'),
#  ('Katong Square[15]', ''),
#  ('Kallang Wave Mall', '/wiki/Kallang_Wave_Mall'),
#  ('Leisure Park Kallang', '/wiki/Leisure_Park_Kallang'),
#  ('i12 Katong', '/wiki/I12_Katong'),
#  ('Our Tampines Hub', '/wiki/Our_Tampines_Hub'),
#  ('Parkway Parade', '/wiki/Parkway_Parade'),
#  ('Pasir Ris West Plaza', ''),
#  ('Paya Lebar Square', ''),
#  ('Paya Lebar Quarter (PLQ)', ''),
#  ('Roxy Square[16]', ''),
#  ('Singpost Centre[17]', ''),
#  ('Tampines 1', '/wiki/Tampines_1'),
#  ('Tampines Mall', '/wiki/Tampines_Mall'),
#  ('White Sands', '/wiki/White_Sands_Shopping_Mall,_Singapore'),
#  ('City Plaza[18]', ''),
#  ('Elias Mall[19]', ''),
#  ('Loyang Point[20]', ''),
#  ('888 Plaza[21]', ''),
#  ('Admiralty Place', ''),
#  ('AMK Hub', '/wiki/AMK_Hub'),
#  ('Canberra Plaza', '/wiki/Canberra_Plaza'),
#  ('Causeway Point', '/wiki/Causeway_Point'),
#  ('Woodlands Civic Centre', ''),
#  ('Broadway Plaza', ''),
#  ('Jubilee Square', ''),
#  ('Junction 8', ''),
#  ('Junction Nine', ''),
#  ('Marsiling Mall', ''),
#  ('Northpoint City', '/wiki/Northpoint_City,_Singapore'),
#  ('Sembawang Shopping Centre', '/wiki/Sembawang_Shopping_Centre'),
#  ('Sun Plaza', '/wiki/Sun_Plaza,_Singapore'),
#  ('Vista Point', ''),
#  ('Wisteria Mall', ''),
#  ('Woodlands Mart', ''),
#  ('Woodlands North Plaza', ''),
#  ('Buangkok Square', ''),
#  ('Compass One', '/wiki/Compass_One'),
#  ('Greenwich V', ''),
#  ('Heartland Mall', '/wiki/Heartland_Mall'),
#  ('Hougang 1', ''),
#  ('Hougang Green Shopping Mall', ''),
#  ('Hougang Mall', '/wiki/Hougang_Mall'),
#  ('NEX', '/wiki/Nex,_Singapore'),
#  ('Northshore Plaza', ''),
#  ('Oasis Terraces', '/wiki/Oasis_Terraces'),
#  ('Punggol Plaza', '/wiki/Punggol_Plaza'),
#  ('Rivervale Mall', ''),
#  ('Rivervale Plaza', ''),
#  ('Sengkang Grand Mall', ''),
#  ('The Seletar Mall', '/wiki/Seletar_Mall'),
#  ('Upper Serangoon Shopping Centre', ''),
#  ('Waterway Point', '/wiki/Waterway_Point'),
#  ('myVillage At Serangoon Garden', ''),
#  ('Beauty World Centre', ''),
#  ('Beauty World Plaza', ''),
#  ('Bukit Panjang Plaza', ''),
#  ('Bukit Timah Plaza', ''),
#  ('Fajar Shopping Centre', ''),
#  ('Greenridge Shopping Centre', ''),
#  ('Hillion Mall', ''),
#  ('HillV2', ''),
#  ('Junction 10', '/wiki/Junction_10'),
#  ('Keat Hong Shopping Centre', ''),
#  ('Limbang Shopping Centre', ''),
#  ('Lot One', '/wiki/Lot_One'),
#  ('Rail Mall', ''),
#  ('Sunshine Place', ''),
#  ('Teck Whye Shopping Centre', ''),
#  ('West Mall', '/wiki/West_Mall'),
#  ('Yew Tee Point', ''),
#  ('Yew Tee Square', ''),
#  ('VivoCity', '/wiki/VivoCity'),
#  ('HarbourFront Centre', '/wiki/HarbourFront_Centre'),
#  ('Alexandra Retail Centre', '/wiki/Alexandra_Retail_Centre'),
#  ('321 Clementi', ''),
#  ('The Clementi Mall', '/wiki/Clementi_Mall'),
#  ('IMM', '/wiki/IMM_(Singapore)'),
#  ('JCube', '/wiki/JCube'),
#  ('Jem', '/wiki/Jem_(shopping_mall)'),
#  ('Westgate', '/wiki/Westgate_(Singapore)'),
#  ('Jurong Point', '/wiki/Jurong_Point_Shopping_Mall'),
#  ('Pioneer Mall', '/wiki/Pioneer_Mall'),
#  ('The Star Vista', '/wiki/One-north#The_Star_Vista'),
#  ('Alexandra Central', ''),
#  ('Anchorpoint', ''),
#  ('OD Mall', ''),
#  ('Boon Lay Shopping Centre', ''),
#  ('Grantral Mall', ''),
#  ('Fairprice Hub', ''),
#  ('Gek Poh Shopping Centre', '/wiki/Gek_Poh_Shopping_Centre'),
#  ('Rochester Mall', ''),
#  ('Taman Jurong Shopping Centre', ''),
#  ('West Coast Plaza', '/wiki/West_Coast_Plaza'),
#  ('Queensway Shopping Centre', '/wiki/Queensway_Shopping_Centre'),
#  ('The Rail Mall', '/wiki/The_Rail_Mall')]

# %%
df = pd.DataFrame(mall_links, columns=['Name', 'Link'])
df.head(10)
# Out:
#                              Name                              Link
# 0                       100 AM[1]
# 1                 313@Somerset[2]
# 2                          Aperia
# 3  Balestier Hill Shopping Centre
# 4                   Bugis Cube[3]
# 5                  Bugis Junction              /wiki/Bugis_Junction
# 6                          Bugis+                    /wiki/Bugis%2B
# 7                  Capitol Piazza              /wiki/Capitol_Piazza
# 8      Cathay Cineleisure Orchard  /wiki/Cathay_Cineleisure_Orchard
# 9             Clarke Quay Central

# %% [markdown]
# #### 1.2 Add Opening Date
# Retrieve opening information from mall's wiki page, if available

# %%
def get_opening_date(url_ext):
    url = f"https://en.wikipedia.org{url_ext}"
    result = requests.get(url)
    doc = BeautifulSoup(result.text, 'html.parser')

    # get the opening date
    opened_row = doc.find('th', string='Opened') or doc.find('th', string='Opening date')
    if opened_row:
        # Find the next sibling of the 'opened_row' which is the 'td' containing the date
        opened_date_cell = opened_row.find_next_sibling('td')
        return opened_date_cell.text or ''
    else:
        return ''

# %%
df['Opening Date'] = df['Link'].apply(get_opening_date)
df.head(10)
# Out:
#                              Name                              Link  \
# 0                       100 AM[1]
# 1                 313@Somerset[2]
# 2                          Aperia
# 3  Balestier Hill Shopping Centre
# 4                   Bugis Cube[3]
# 5                  Bugis Junction              /wiki/Bugis_Junction
# 6                          Bugis+                    /wiki/Bugis%2B
# 7                  Capitol Piazza              /wiki/Capitol_Piazza
# 8      Cathay Cineleisure Orchard  /wiki/Cathay_Cineleisure_Orchard
# 9             Clarke Quay Central
#
#                                    Opening Date
# 0
# 1
# 2
# 3
# 4
# 5  September 8, 1995; 28 years ago (1995-09-08)
# 6                        1 June 2009 (as Iluma)
# 7                                    March 2015
# 8                                          1997
# 9

# %% [markdown]
# #### 1.3 Add Geocoordinates
# Use OneMap SG API to retrieve coordinate information, if available

# %%
def get_geocoordinates_from_address(address: str) -> tuple:
    url = f"https://www.onemap.gov.sg/api/common/elastic/search?searchVal={address}&returnGeom=Y&getAddrDetails=Y&pageNum=1"
    
    response = requests.get(url)    
    data = response.json()

    # Check if there are results
    if data['results']:
        first_result = data['results'][0]
        latitude = first_result['LATITUDE']
        longitude = first_result['LONGITUDE']
        return (latitude, longitude)
    else:
        return ("", "")

# %%
df[['Latitude', 'Longitude']] = df['Name'].apply(lambda address: pd.Series(get_geocoordinates_from_address(address)))
df.head(10)
# Out:
#                              Name                              Link  \
# 0                       100 AM[1]
# 1                 313@Somerset[2]
# 2                          Aperia
# 3  Balestier Hill Shopping Centre
# 4                   Bugis Cube[3]
# 5                  Bugis Junction              /wiki/Bugis_Junction
# 6                          Bugis+                    /wiki/Bugis%2B
# 7                  Capitol Piazza              /wiki/Capitol_Piazza
# 8      Cathay Cineleisure Orchard  /wiki/Cathay_Cineleisure_Orchard
# 9             Clarke Quay Central
#
#                                    Opening Date          Latitude  \
# 0                                                1.28155949555229
# 1                                                1.30101436404056
# 2                                                 1.3097112065077
# 3                                                1.32559594839311
# 4
# 5  September 8, 1995; 28 years ago (1995-09-08)   1.2991371723215
# 6                        1 June 2009 (as Iluma)  1.30095171530648
# 7                                    March 2015  1.29307884763132
# 8                                          1997  1.30149264852924
# 9
#
#           Longitude
# 0  103.847208361003
# 1  103.838360664485
# 2  103.864326436447
# 3  103.842571612968
# 4
# 5  103.855450325604
# 6  103.855172625542
# 7  103.851261982149
# 8  103.836406753067
# 9

# %%
df.describe()
# Out:
#               Name Link Opening Date Latitude Longitude
# count          169  169          169      169       169
# unique         168   91           69      143       143
# top     Junction 8
# freq             2   79           96       25        25

# %% [markdown]
# #### 1.4 Save to CSV
# This dataset is based on web scraping data, but appears to be significantly incomplete. Additional data will be added manually

# %%
df.to_csv('../data/modified/malls_dataset_v1.csv')

# %% [markdown]
# #### 1.5 Conduct EDA + Data Cleaning
# Check missing data and manually add information
# - Unable to find the coordinates of 17 malls via the API. They either do not exist or have been closed down.

# %% [markdown]
# Of the above, the followings malls have been closed:
# - The Verge
# - City Vibe
# - JCube
# - Jurong Entertainment Centre
# - Ellenborough Market
# - Capitol Centre
# - Amber Mansions
# - Serangoon Plaza
# - Specialist Shopping Centre
#
# The coordinates of the following malls are manually added:
# - Clarke Quay Central
# - Scotts Shopping Centre -> Scotts Square
# - Shaw House and Centre -> Shaw House
# - Mandarin Gallery
# - Cosford Container Park
# - Change Alley

# %%
raw_df = pd.read_csv('../data/modified/malls_dataset_v1.csv')
raw_df = raw_df.drop(columns=['Unnamed: 0', 'Link'])
raw_df.head(10)
# Out:
#                              Name  \
# 0                       100 AM[1]
# 1                 313@Somerset[2]
# 2                          Aperia
# 3  Balestier Hill Shopping Centre
# 4                   Bugis Cube[3]
# 5                  Bugis Junction
# 6                          Bugis+
# 7                  Capitol Piazza
# 8      Cathay Cineleisure Orchard
# 9             Clarke Quay Central
#
#                                    Opening Date  Latitude   Longitude
# 0                                           NaN  1.281559  103.847208
# 1                                           NaN  1.301014  103.838361
# 2                                           NaN  1.309711  103.864326
# 3                                           NaN  1.325596  103.842572
# 4                                           NaN       NaN         NaN
# 5  September 8, 1995; 28 years ago (1995-09-08)  1.299137  103.855450
# 6                        1 June 2009 (as Iluma)  1.300952  103.855173
# 7                                    March 2015  1.293079  103.851262
# 8                                          1997  1.301493  103.836407
# 9                                           NaN       NaN         NaN

# %%
malls_no_coordinates = raw_df[raw_df['Latitude'].isna()]
malls_no_coordinates.head(5)
# Out:
#                              Name Opening Date  Latitude  Longitude
# 4                   Bugis Cube[3]          NaN       NaN        NaN
# 9             Clarke Quay Central          NaN       NaN        NaN
# 12              City Gate Mall[4]          NaN       NaN        NaN
# 19  Holland Village Shopping Mall          NaN       NaN        NaN
# 22               Knightsbridge[5]          NaN       NaN        NaN

# %%
malls_no_opening_dates = raw_df[raw_df['Opening Date'].isna()]
malls_no_opening_dates.head(5)
# Out:
#                              Name Opening Date  Latitude   Longitude
# 0                       100 AM[1]          NaN  1.281559  103.847208
# 1                 313@Somerset[2]          NaN  1.301014  103.838361
# 2                          Aperia          NaN  1.309711  103.864326
# 3  Balestier Hill Shopping Centre          NaN  1.325596  103.842572
# 4                   Bugis Cube[3]          NaN       NaN         NaN

# %% [markdown]
# The rest of the data has been manually updated and saved to malls_dataset.csv

# %% [markdown]
# #### 2.1 Calculating malls2kmRadius

# %%
import pandas as pd

malls_df = pd.read_csv('../data/modified/malls_dataset.csv')
malls_df.head(10)
# Out:
#    Unnamed: 0                            name  latitude  longitude  \
# 0           0                          100 AM  1.274683   103.8435
# 1           1                    313@Somerset  1.301014   103.8384
# 2           2                          Aperia  1.309711   103.8643
# 3           3  Balestier Hill Shopping Centre  1.325596   103.8426
# 4           4                      Bugis Cube  1.298141   103.8556
# 5           5                  Bugis Junction  1.299137   103.8555
# 6           6                          Bugis+  1.300952   103.8552
# 7           7                  Capitol Piazza  1.293079   103.8513
# 8           8      Cathay Cineleisure Orchard  1.301521   103.8364
# 9           9                 The Centrepoint  1.301450   103.8400
#
#   opening_date
# 0    1/12/2014
# 1    3/12/2009
# 2     5/5/2014
# 3     1/1/1974
# 4     1/1/2009
# 5     8/9/1995
# 6    28/6/2012
# 7     1/3/2015
# 8     1/5/1999
# 9     1/1/1983

# %%
# reformat date
from datetime import datetime

malls_df['opening_date'] = malls_df['opening_date'].apply(lambda date: datetime.strptime(date, "%d/%m/%Y"))

# %%
malls_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    161 non-null    int64
#  1   name          161 non-null    object
#  2   latitude      161 non-null    float64
#  3   longitude     161 non-null    float64
#  4   opening_date  161 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1)
# memory usage: 6.4+ KB

# %%
class Coordinate:
    def __init__(self, lon, lat):
        self.lon = lon
        self.lat = lat

    def get_lon(self):
        return self.lon
    
    def get_lat(self):
        return self.lat
    
    def get_lat_lon(self):
        return (self.lat, self.lon)

# %%
from geopy.distance import geodesic

def calculate_distance(start: Coordinate, end: Coordinate) -> float:
    return geodesic(start.get_lat_lon(), end.get_lat_lon()).km

# %%
from datetime import datetime

# %%
def get_names_of_malls_within_2km_of_hdb(hdb_coordinate: Coordinate, hdb_record_date: datetime, malls_df: pd.DataFrame) -> list:
    malls_within_2km = []

    for index, row in malls_df.iterrows():
        distance2hdb = calculate_distance(hdb_coordinate, Coordinate(lat=row['latitude'], lon=row['longitude']))
        if distance2hdb <= 2 and row['opening_date'] < hdb_record_date:
            malls_within_2km.append(f"{row['name']} ({round(distance2hdb * 100 * 1000) / 100}m)")

    return malls_within_2km

# %%
get_names_of_malls_within_2km_of_hdb(
    Coordinate(lat=1.37509746867904, lon=103.83761896123), 
    datetime(2024, 2, 4),
    malls_df
)
# Out:
# ['AMK Hub (1365.57m)', 'Broadway Plaza (985.61m)', 'Jubilee Square (1190.72m)']

# %% [markdown]
# 1. Read resale transaction data
# 2. Reformat datetime
# 3. Run apply function

# %%
hdb_transactions = pd.read_csv('../data/modified/hdb_working_data.csv')
print(hdb_transactions.shape)
hdb_transactions.head()
# Out:
# (211395, 24)
#    Unnamed: 0    month        town flat_type block        street_name  \
# 0           0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4
# 1           1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10
# 2           2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4
# 3           3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10
# 4           4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10
#
#   storey_range  floor_area_sqm      flat_model  lease_commence_date  ...  \
# 0     07 TO 09            60.0        Improved                 1986  ...
# 1     01 TO 03            68.0  New Generation                 1981  ...
# 2     01 TO 03            69.0  New Generation                 1980  ...
# 3     01 TO 03            68.0  New Generation                 1979  ...
# 4     07 TO 09            68.0  New Generation                 1980  ...
#
#     longitude      sora               mrt_stations_within_1km  \
# 0  103.837619  0.129019                                    []
# 1  103.855621  0.129019  ['Ang Mo Kio MRT Station (811.53m)']
# 2  103.838169  0.129019                                    []
# 3  103.855357  0.129019  ['Ang Mo Kio MRT Station (703.32m)']
# 4  103.857736  0.129019  ['Ang Mo Kio MRT Station (939.42m)']
#
#                    nearest_mrt_station  bto_within_4km  bto_supply_within_4km  \
# 0  Yio Chu Kang MRT Station (1099.56m)              12                   6587
# 1     Ang Mo Kio MRT Station (811.53m)              39                  23252
# 2   Yio Chu Kang MRT Station (1183.8m)              10                   4941
# 3     Ang Mo Kio MRT Station (703.32m)              34                  20043
# 4     Ang Mo Kio MRT Station (939.42m)              45                  26356
#
#                                  pri_schs_within_1km  \
# 0  ['Ang Mo Kio Primary School (676.95m)', "CHIJ ...
# 1             ['Jing Shan Primary School (431.03m)']
# 2  ['Ang Mo Kio Primary School (495.36m)', "CHIJ ...
# 3  ['Jing Shan Primary School (611.18m)', 'Teck G...
# 4             ['Jing Shan Primary School (627.43m)']
#
#   count_pri_schs_within_1km  distance2cbd  \
# 0                         3      9.764087
# 1                         1      9.515643
# 2                         3      9.585589
# 3                         3      8.833708
# 4                         1      9.275781
#
#                                 mallsWithin2kmRadius
# 0  AMK Hub (8128.9m), Broadway Plaza (8526.07m), ...
# 1  AMK Hub (8128.9m), Broadway Plaza (8526.07m), ...
# 2  AMK Hub (8128.9m), Broadway Plaza (8526.07m), ...
# 3  AMK Hub (8128.9m), Broadway Plaza (8526.07m), ...
# 4  AMK Hub (8128.9m), Broadway Plaza (8526.07m), ...
#
# [5 rows x 24 columns]

# %%
hdb_transactions['record_date'] = hdb_transactions['month'].apply(lambda date: datetime.strptime(date, "%Y-%m"))
hdb_transactions.head()
# Out:
#    Unnamed: 0    month        town flat_type block        street_name  \
# 0           0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4
# 1           1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10
# 2           2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4
# 3           3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10
# 4           4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10
#
#   storey_range  floor_area_sqm      flat_model  lease_commence_date  ...  \
# 0     07 TO 09            60.0        Improved                 1986  ...
# 1     01 TO 03            68.0  New Generation                 1981  ...
# 2     01 TO 03            69.0  New Generation                 1980  ...
# 3     01 TO 03            68.0  New Generation                 1979  ...
# 4     07 TO 09            68.0  New Generation                 1980  ...
#
#        sora               mrt_stations_within_1km  \
# 0  0.129019                                    []
# 1  0.129019  ['Ang Mo Kio MRT Station (811.53m)']
# 2  0.129019                                    []
# 3  0.129019  ['Ang Mo Kio MRT Station (703.32m)']
# 4  0.129019  ['Ang Mo Kio MRT Station (939.42m)']
#
#                    nearest_mrt_station  bto_within_4km  bto_supply_within_4km  \
# 0  Yio Chu Kang MRT Station (1099.56m)              12                   6587
# 1     Ang Mo Kio MRT Station (811.53m)              39                  23252
# 2   Yio Chu Kang MRT Station (1183.8m)              10                   4941
# 3     Ang Mo Kio MRT Station (703.32m)              34                  20043
# 4     Ang Mo Kio MRT Station (939.42m)              45                  26356
#
#                                  pri_schs_within_1km  \
# 0  ['Ang Mo Kio Primary School (676.95m)', "CHIJ ...
# 1             ['Jing Shan Primary School (431.03m)']
# 2  ['Ang Mo Kio Primary School (495.36m)', "CHIJ ...
# 3  ['Jing Shan Primary School (611.18m)', 'Teck G...
# 4             ['Jing Shan Primary School (627.43m)']
#
#   count_pri_schs_within_1km distance2cbd  \
# 0                         3     9.764087
# 1                         1     9.515643
# 2                         3     9.585589
# 3                         3     8.833708
# 4                         1     9.275781
#
#                                 mallsWithin2kmRadius  record_date
# 0  AMK Hub (8128.9m), Broadway Plaza (8526.07m), ...   2015-01-01
# 1  AMK Hub (8128.9m), Broadway Plaza (8526.07m), ...   2015-01-01
# 2  AMK Hub (8128.9m), Broadway Plaza (8526.07m), ...   2015-01-01
# 3  AMK Hub (8128.9m), Broadway Plaza (8526.07m), ...   2015-01-01
# 4  AMK Hub (8128.9m), Broadway Plaza (8526.07m), ...   2015-01-01
#
# [5 rows x 25 columns]

# %% [markdown]
# #### 2.2 Run calculations by chunk for better tracking

# %%
import numpy as np

chunks = np.array_split(hdb_transactions, 5)

result_chunks = []

for i, chunk in enumerate(chunks):
    print(f"Starting chunk: {i+1}")
    result_chunk = chunk.copy()
    result_chunk['mallsWithin2kmRadius'] = chunk.apply(lambda row: get_names_of_malls_within_2km_of_hdb(
        Coordinate(lat=row['latitude'], lon=row['longitude']), 
        row['record_date'],
        malls_df
    ), axis=1)

    result_chunks.append(result_chunk)

    combined_df = pd.concat(result_chunks)
    combined_df.to_csv('../data/modified/temporary.csv', index=False)
    print(f"Finished chunk: {i+1}")
# Out:
# /Users/joesurf/Documents/NUS/BZA/Y3S2/BT4222/Housing-Price-Time-Series-Forecasting/env/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# Starting chunk: 1
# Finished chunk: 1
# Starting chunk: 2
# Finished chunk: 2
# Starting chunk: 3
# Finished chunk: 3
# Starting chunk: 4
# Finished chunk: 4
# Starting chunk: 5
# Finished chunk: 5

# %%
combined_df.head()
# Out:
#    Unnamed: 0    month        town flat_type block        street_name  \
# 0           0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4
# 1           1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10
# 2           2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4
# 3           3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10
# 4           4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10
#
#   storey_range  floor_area_sqm      flat_model  lease_commence_date  ...  \
# 0     07 TO 09            60.0        Improved                 1986  ...
# 1     01 TO 03            68.0  New Generation                 1981  ...
# 2     01 TO 03            69.0  New Generation                 1980  ...
# 3     01 TO 03            68.0  New Generation                 1979  ...
# 4     07 TO 09            68.0  New Generation                 1980  ...
#
#        sora               mrt_stations_within_1km  \
# 0  0.129019                                    []
# 1  0.129019  ['Ang Mo Kio MRT Station (811.53m)']
# 2  0.129019                                    []
# 3  0.129019  ['Ang Mo Kio MRT Station (703.32m)']
# 4  0.129019  ['Ang Mo Kio MRT Station (939.42m)']
#
#                    nearest_mrt_station  bto_within_4km  bto_supply_within_4km  \
# 0  Yio Chu Kang MRT Station (1099.56m)              12                   6587
# 1     Ang Mo Kio MRT Station (811.53m)              39                  23252
# 2   Yio Chu Kang MRT Station (1183.8m)              10                   4941
# 3     Ang Mo Kio MRT Station (703.32m)              34                  20043
# 4     Ang Mo Kio MRT Station (939.42m)              45                  26356
#
#                                  pri_schs_within_1km  \
# 0  ['Ang Mo Kio Primary School (676.95m)', "CHIJ ...
# 1             ['Jing Shan Primary School (431.03m)']
# 2  ['Ang Mo Kio Primary School (495.36m)', "CHIJ ...
# 3  ['Jing Shan Primary School (611.18m)', 'Teck G...
# 4             ['Jing Shan Primary School (627.43m)']
#
#   count_pri_schs_within_1km distance2cbd  \
# 0                         3     9.764087
# 1                         1     9.515643
# 2                         3     9.585589
# 3                         3     8.833708
# 4                         1     9.275781
#
#                                 mallsWithin2kmRadius  record_date
# 0  [AMK Hub (1365.57m), Broadway Plaza (985.61m),...   2015-01-01
# 1  [AMK Hub (937.75m), Broadway Plaza (1103.92m),...   2015-01-01
# 2  [AMK Hub (1238.44m), Broadway Plaza (878.7m), ...   2015-01-01
# 3  [AMK Hub (784.06m), Broadway Plaza (1149.31m),...   2015-01-01
# 4  [AMK Hub (1057.2m), Broadway Plaza (1317.66m),...   2015-01-01
#
# [5 rows x 25 columns]

# %%
combined_df = combined_df.drop(['record_date', 'Unnamed: 0'], axis=1)

# %%
combined_df.to_csv('../data/modified/hdb_working_data.csv')
